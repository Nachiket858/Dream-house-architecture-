# %%
import os
from openai import OpenAI

# Set your API key directly (NOT RECOMMENDED for production, use environment variables instead)
api_key = "eyJhbGciOiJIUzI1NiIsImtpZCI6IlV6SXJWd1h0dnprLVRvdzlLZWstc0M1akptWXBvX1VaVkxUZlpnMDRlOFUiLCJ0eXAiOiJKV1QifQ..F1NxKPImHBSmQ7W5uENvZcQKZX5TjfsYmjdFZoGbaJE"

client = OpenAI(
    base_url="https://api.studio.nebius.com/v1/",
    api_key=api_key
)

response = client.images.generate(
    model="black-forest-labs/flux-schnell",
    prompt="create image of cat",
    response_format="b64_json",
    extra_body={
        "response_extension": "png",
        "width": 1024,
        "height": 1024,
        "num_inference_steps": 4,
        "negative_prompt": "",
        "seed": -1
    }
)

print(response.to_json())

# %%
print(response)
# Out:
# <bound method BaseModel.to_json of ImagesResponse(created=None, data=[Image(b64_json='...', revised_prompt=None, url=None)], usage=None, id='text2img-4d1083b8-c550-479b-850f-0321f7640187')>

# %%
import base64

# Get base64 string from response
b64_data = response.data["b64_json"]

# Decode and save to a file
with open("generated_image.png", "wb") as f:
    f.write(base64.b64decode(b64_data))

# Optional: Open the image (if you're on desktop)
from PIL import Image
img = Image.open("generated_image.png")
img.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 import base64
#       3 # Get base64 string from response
# ----> 4 b64_data = response.data["b64_json"]
#       6 # Decode and save to a file
#       7 with open("generated_image.png", "wb") as f:
#
# AttributeError: 'function' object has no attribute 'data'

# %%
import os
import base64
from openai import OpenAI
from PIL import Image
from io import BytesIO

# API setup
api_key = "eyJhbGciOiJIUzI1NiIsImtpZCI6IlV6SXJWd1h0dnprLVRvdzlLZWstc0M1akptWXBvX1VaVkxUZlpnMDRlOFUiLCJ0eXAiOiJKV1QifQ..F1NxKPImHBSmQ7W5uENvZcQKZX5TjfsYmjdFZoGbaJE"

client = OpenAI(
    base_url="https://api.studio.nebius.com/v1/",
    api_key=api_key
)

# Generate image
response = client.images.generate(
    model="black-forest-labs/flux-schnell",
    prompt="create image of cat",
    response_format="b64_json",
    extra_body={
        "response_extension": "png",
        "width": 1024,
        "height": 1024,
        "num_inference_steps": 4,
        "negative_prompt": "",
        "seed": -1
    }
)

# Extract and decode image
b64_data = response.data[0]["b64_json"]
image_bytes = base64.b64decode(b64_data)

# Show image using PIL
image = Image.open(BytesIO(image_bytes))
image.show()

# Optional: save image
image.save("generated_cat.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 31
#      16 response = client.images.generate(
#      17     model="black-forest-labs/flux-schnell",
#      18     prompt="create image of cat",
#    (...)     27     }
#      28 )
#      30 # Extract and decode image
# ---> 31 b64_data = response.data[0]["b64_json"]
#      32 image_bytes = base64.b64decode(b64_data)
#      34 # Show image using PIL
#
# TypeError: 'Image' object is not subscriptable

# %%
api_key = "eyJhbGciOiJIUzI1NiIsImtpZCI6IlV6SXJWd1h0dnprLVRvdzlLZWstc0M1akptWXBvX1VaVkxUZlpnMDRlOFUiLCJ0eXAiOiJKV1QifQ..F1NxKPImHBSmQ7W5uENvZcQKZX5TjfsYmjdFZoGbaJE"

# %%
import os
import base64
from openai import OpenAI
from PIL import Image
from io import BytesIO

# API setup
# api_key = "eyJhbGciOiJIUzI1NiIsImtpZCI6IlV6..."  # Truncated for brevity

client = OpenAI(
    base_url="https://api.studio.nebius.com/v1/",
    api_key=api_key
)

# Generate image
response = client.images.generate(
    model="black-forest-labs/flux-schnell",
    prompt="create image of cat",
    response_format="b64_json",
    extra_body={
        "response_extension": "png",
        "width": 1024,
        "height": 1024,
        "num_inference_steps": 4,
        "negative_prompt": "",
        "seed": -1
    }
)

# ✅ Access the base64 image correctly
b64_data = response.data[0].b64_json
image_bytes = base64.b64decode(b64_data)

# Display and save
image = Image.open(BytesIO(image_bytes))
image.show()                        # Opens the image viewer
# image.save("generated_cat.png")    # Optional: save to file
